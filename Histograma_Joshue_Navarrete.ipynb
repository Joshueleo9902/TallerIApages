# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshueleo9902/TallerIApages/blob/gh-pages/Histograma_Joshue_Navarrete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar Virtual Lenv
# !pip install virtualenv
# Out:
# ...
#      |████████████████████████████████| 5.3 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 338 kB 46.8 MB/s
# ...

# %%
# Creando un entorno virtual
# !virtualenv miEntorno -p python3
#Activando entorno virtual
# !source miEntorno/bin/activate
# Out:
# created virtual environment CPython3.7.11.final.0-64 in 811ms
#   creator CPython3Posix(dest=/content/miEntorno, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==21.2.3, setuptools==57.4.0, wheel==0.37.0
#   activators BashActivator,CShellActivator,FishActivator,PowerShellActivator,PythonActivator

# %%
#Librerias 
import numpy as np
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
# Ejercicio pregunta 3 examen - Joshue Navarrete 
#Generar la imagen en escala de  grises y el histograma
url2= 'https://placekitten.com/800/577'
myImg = io.imread(url2)
myGrayImg = cv.cvtColor(myImg, cv.COLOR_BGR2GRAY)
cv2_imshow(myGrayImg)
plt.hist(myGrayImg.ravel(),bins = 256, range = [0, 256])
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=800x577 at 0x7F3F15E65210>
